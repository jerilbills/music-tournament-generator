# %% [markdown]
# Author 1: Jeril Bills
#
# Author 2: Aric Bills
#
# Date: September/October 2021
#
# Description: Puts a list of artists into a tournament. For list lengths that are powers of 2, it shuffles a list that can then be used to stage a knockout tournament. For all other list lengths, it sorts artists into groups of 4-8 and schedules a round-robin tournament for each group.

# %% [markdown]
# Function to take a list of artists and read the file;
# Function takes one argument, filename, which should be a .txt file;
# with makes sure that it closes the file when done after opening.;
# "r" is to open the file for reading - it's also the default;
# strip() removes the white space at the beginning and end of the file;
# splitlines() converts the document into a list, with each line of the file as a list item

# %%
def read_list(filename):
    with open(filename, "r", encoding = "utf-8") as f:
        return f.read().strip().splitlines()

# %% [markdown]
# Function to check whether a number is a power of 2

# %%
import math
def is_power2(num):
    power2 = math.log2(num)
    return math.isclose(power2, round(power2))

# %% [markdown]
# Function to determine the number of groups;
# Why did we do the math this way? The number of groups must be a power of 2, and there must be no more than 8 and no less than 4 per group. So the upper bound (the most possible groups) is listnum/4, and the lower bound (fewest possible groups) is listnum/8. Because 8 is one power of 2 higher than 4, log2 of listnum/8 will always be 1 less than log2 of listnum/4. converting math.log2(listnum/4) automatically returns the power to which we need to raise 2 in order to get the number of groups, since int will round down to the nearest whole integer, and log2 of listnum/4 is our upper bound.

# %%
def num_groups(listnum):
    return 2**int(math.log2(listnum/4))

# %% [markdown]
# Function to assign artists to groups;
# First we created four variables;
# group_num tells us how many groups to create for this list;
# per_group tells us the average number of aritsts per group;
# artists starts out as an empty list, but will ultimately contain the contents of each group with each group as a list;
# start is set at 0 to begin with, since this will be the first start index value from which to start the first group;
# iterate through total number of groups; group_num + 1 since the end value doesn't get iterated over, that's where it stops - the reason we did this instead of range(group_num) is because we're multiplying the average number of artists per group by this value each time;
# end is set to round. This allows us distribute larger and smaller group numbers evenly throughout;
# initial start value is 0 and the initial end value is the average number of artists rounded to the nearest whole number. This will create a list within the artists list of the first however many is the average number of aritsts rounded to the nearest whole number, which will constitute our first group. Since Python stops at the end value without including it, this works out perfectly, since the starting index is 0 and so the last item we want will be the average artist rounded number minus 1;
# We then assign the current end index as the start of the next one so we can get the next group of artists.

# %%
def assign_groups(artlst):
    group_num = num_groups(len(artlst))
    per_group = len(artlst) / group_num
    artists = []
    start = 0
    for i in range(1, group_num + 1):
        end = round(i * per_group)
        artists.append(artlst[start:end])
        start = end
    return artists

# %% [markdown]
# Function to sort a list of artists into groups;
# Takes an argument, filename, the name of a text file containing a human list; reads the file and turns it into a python list; shuffles the list; tests whether the list is a power of 2 - if not, break the list into groups such that the number of groups is a power of 2 and the group size is between 4 and 8, and keeping the groups as similar in size as possible, with different-size groups spread evenly throughout; if the list is a power of 2, simply returns the shuffled list.

# %%
import random
def group_artists(filename):
    artist_list = read_list(filename)
    random.shuffle(artist_list)
    if is_power2(len(artist_list)) == False:
        return assign_groups(artist_list)
    else: 
        return artist_list

# %% [markdown]
# Okay, so now that I've done that, what I want to do now is
# 1. print this out in a nice, neat, readable way - for starters.
# 2. But then I also want it to create my schedule for me such that every artist battles every other artist once. Ideally, I would like it to do this the way I do it.

# %% [markdown]
# Schedule: I think what I want to maybe do is put these into tuples, but I need a way to keep track of who has been picked already. From the list of artists in each group, pick one at random, take the one picked off the list, and then pick another one at random.That's easy. The first day is simple. Do that until there are fewer than 2 artists left. But the next part is trickier. I need a way to pick an artist at random from the list, but then temporarily exclude artists that have already been paired with them, so that the same two artists cannot be paired twice.

# %% [markdown]
# My preferred way:
#
# 1. Pick an artist at random from the group
# 2. Pick a second artists at random from the group, different from the first artist and pair the artists together, first artist vs. second artist
# 3. Keep pairing artists without repeating any until there are fewer than 2 left
# 4. Repeat until every arist has been paired with every other arist once. Prevent aritsts from being paired with the same artist twice.
#
# One possible (maybe easier?) way:
#
# 1. set it up so you have 1 vs. 2, 1 vs. 3, 1 vs. 4, etc., then 2 vs. 3, 2 vs. 4, etc.
#
# Then I could possibly randomize it by shuffling the paired values
#
# Ooh, one way I could achieve the same effect as above would be to do the easier? way, then shuffle pairs, then go through each pair generating a random number (1 or 0 or 1 or 2) like a coinflip to determine whether to keep the pairs in the same order or to flip the order. - Such a program would actually be hella useful once I get to the knockout stage, anyway.
#
# So, the idea is:
#
# 1. Pair each arist with each other artists once, 1-2, 1-3, 1-4 ... 2-3, 2-4 ...
# 2. shuffle these pairings
# 3. do a "coin toss" on each pairing to determine whether to keep the order the same or reverse it.

# %% [markdown]
# 1. use a for loop to iterate through each group, and a nested for loop to iterate through the artists in each group. How do I keep the groups separate, though? And also, is there a more efficient way to do this, since this would be an exponential algorithm, wouldn't it?
#
# Actually - first I have to actually group the artists, no?

# %% [markdown]
# pairs_order is a coin-toss function that randomly decides whether to reverse the order of a pairing or leave it the same. First it pairs each artist in the group with each other artist exactly once; then it shuffles the pairings; then for each pairing, at random 50-50, it either leaves the pairing in the same order or reverses the order
#
# print_group prints out the artists in the group in a neat, readable way
#
# print_pairs prints out the matchups in a neat, readable way
#
# print_artists takes a list, puts it in groups and pairings, and then prints out the entire tournament groups and pairings. First it uses the group artists function to put artists into groups; then it uses the print_group function to print the group, followed by the print_pairs function to print the matchups. It does this for each group, printing first the artists in the group, then the matchups.

# %%
import itertools
def pairs_order(group):
    pairings = list(itertools.combinations(group, 2))
    random.shuffle(pairings)
    pairings = [(first, second) if random.randrange(2) else (second, first) 
        for (first, second) in pairings]
    return pairings

def print_group(group, group_no):
    print(f"Group {group_no}:")
    print("\n".join(group))

def print_pairs(pairs):
    for (first, second) in pairs:
        print(f"{first} vs. {second}")
    
def pair_artists(filename):
    groups = group_artists(filename)
    for i, group in enumerate(groups, start=1):
        print_group(group,  i)
        print()
        print_pairs(pairs_order(group))
        print()

# %%
pair_artists("housetourney.txt")
# Out:
# Group 1:
# Deadmau5
# David Morales
# Danny Rampling
# Jonas Blue
# Porter Robinson
#
# David Morales vs. Jonas Blue
# David Morales vs. Deadmau5
# Porter Robinson vs. Danny Rampling
# Porter Robinson vs. Jonas Blue
# Deadmau5 vs. Jonas Blue
# David Morales vs. Porter Robinson
# Danny Rampling vs. Deadmau5
# Porter Robinson vs. Deadmau5
# David Morales vs. Danny Rampling
# Danny Rampling vs. Jonas Blue
#
# Group 2:
# Yazz
# Frankie Knuckles
# Tony Humphries
# Ron Hardy
# Green Velvet
#
# Yazz vs. Tony Humphries
# Green Velvet vs. Ron Hardy
# Tony Humphries vs. Frankie Knuckles
# Yazz vs. Frankie Knuckles
# Yazz vs. Ron Hardy
# Tony Humphries vs. Ron Hardy
# Green Velvet vs. Yazz
# Tony Humphries vs. Green Velvet
# Frankie Knuckles vs. Green Velvet
# Ron Hardy vs. Frankie Knuckles
#
# Group 3:
# Wolfgang Gartner
# Lady Gaga
# Fedde Le Grand
# J.M. Silk
#
# Lady Gaga vs. Fedde Le Grand
# Wolfgang Gartner vs. Lady Gaga
# Fedde Le Grand vs. J.M. Silk
# Wolfgang Gartner vs. Fedde Le Grand
# Wolfgang Gartner vs. J.M. Silk
# Lady Gaga vs. J.M. Silk
#
# Group 4:
# Raze
# Larry Heard
# Jim Burgess
# Jesse Saunders
# The KLF
#
# Jim Burgess vs. Larry Heard
# The KLF vs. Jim Burgess
# Jim Burgess vs. Raze
# The KLF vs. Larry Heard
# The KLF vs. Raze
# The KLF vs. Jesse Saunders
# Jesse Saunders vs. Raze
# Larry Heard vs. Raze
# Jesse Saunders vs. Larry Heard
# Jesse Saunders vs. Jim Burgess
#
# Group 5:
# Swedish House Mafia
# Marshall Jefferson
# Alesso
# Frankie Knuckles
# Usher
#
# Usher vs. Frankie Knuckles
# Swedish House Mafia vs. Marshall Jefferson
# Alesso vs. Swedish House Mafia
# Usher vs. Alesso
# Swedish House Mafia vs. Frankie Knuckles
# Usher vs. Swedish House Mafia
# Frankie Knuckles vs. Marshall Jefferson
# Marshall Jefferson vs. Usher
# Alesso vs. Frankie Knuckles
# Alesso vs. Marshall Jefferson
#
# Group 6:
# Marshall Jefferson
# Matt Zo
# Beyonce
# Booka Shade
# Aly-Us
#
# Beyonce vs. Matt Zo
# Marshall Jefferson vs. Beyonce
# Booka Shade vs. Matt Zo
# Booka Shade vs. Marshall Jefferson
# Marshall Jefferson vs. Matt Zo
# Beyonce vs. Booka Shade
# Aly-Us vs. Beyonce
# Marshall Jefferson vs. Aly-Us
# Matt Zo vs. Aly-Us
# Booka Shade vs. Aly-Us
#
# Group 7:
# Giorgio Morodoer
# Chip E.
# Farley "Jackmaster" Funk
# Chip E.
# John Robie
#
# Giorgio Morodoer vs. John Robie
# Chip E. vs. Chip E.
# John Robie vs. Chip E.
# John Robie vs. Farley "Jackmaster" Funk
# Chip E. vs. Giorgio Morodoer
# Farley "Jackmaster" Funk vs. Chip E.
# Farley "Jackmaster" Funk vs. Giorgio Morodoer
# John Robie vs. Chip E.
# Chip E. vs. Giorgio Morodoer
# Farley "Jackmaster" Funk vs. Chip E.
#
# Group 8:
# Drake
# Derrick Carter
# Robert Ozn
# Nicky Romero
#
# Derrick Carter vs. Nicky Romero
# Robert Ozn vs. Nicky Romero
# Derrick Carter vs. Drake
# Robert Ozn vs. Drake
# Drake vs. Nicky Romero
# Derrick Carter vs. Robert Ozn
#
# Group 9:
# Coldcut
# Justice
# Janet Jackson
# Kerri Chandler
# Joe Smooth
#
# Coldcut vs. Kerri Chandler
# Janet Jackson vs. Justice
# Joe Smooth vs. Justice
# Coldcut vs. Joe Smooth
# Janet Jackson vs. Coldcut
# Coldcut vs. Justice
# Kerri Chandler vs. Justice
# Joe Smooth vs. Janet Jackson
# Kerri Chandler vs. Janet Jackson
# Joe Smooth vs. Kerri Chandler
#
# Group 10:
# MARRS
# Technotronic
# "Evil" Eddie Richards
# Afrojack
# Avicii
#
# "Evil" Eddie Richards vs. Avicii
# "Evil" Eddie Richards vs. Technotronic
# MARRS vs. Afrojack
# Afrojack vs. "Evil" Eddie Richards
# Afrojack vs. Technotronic
# Avicii vs. MARRS
# Technotronic vs. Avicii
# MARRS vs. "Evil" Eddie Richards
# Avicii vs. Afrojack
# MARRS vs. Technotronic
#
# Group 11:
# DJ Rush
# Charanjit Singh
# Bob Sinclair
# Tyree Cooper
# Donna Summer
#
# Tyree Cooper vs. DJ Rush
# Bob Sinclair vs. DJ Rush
# Donna Summer vs. Charanjit Singh
# DJ Rush vs. Charanjit Singh
# Bob Sinclair vs. Charanjit Singh
# Tyree Cooper vs. Donna Summer
# Bob Sinclair vs. Donna Summer
# Bob Sinclair vs. Tyree Cooper
# Charanjit Singh vs. Tyree Cooper
# DJ Rush vs. Donna Summer
#
# Group 12:
# Lil Louis
# St. Germain
# Bingo Players
# Junior Vasquez
# Justin Berkmann
#
# Bingo Players vs. Lil Louis
# Justin Berkmann vs. Bingo Players
# Junior Vasquez vs. Lil Louis
# St. Germain vs. Junior Vasquez
# Lil Louis vs. Justin Berkmann
# Junior Vasquez vs. Justin Berkmann
# Lil Louis vs. St. Germain
# St. Germain vs. Justin Berkmann
# Junior Vasquez vs. Bingo Players
# St. Germain vs. Bingo Players
#
# Group 13:
# Paul Oakenfold
# Benny Benassi
# Steve Aoki
# Ron Hardy
# Daft Punk
#
# Paul Oakenfold  vs. Steve Aoki
# Ron Hardy vs. Daft Punk
# Paul Oakenfold  vs. Benny Benassi
# Ron Hardy vs. Benny Benassi
# Steve Aoki vs. Benny Benassi
# Ron Hardy vs. Steve Aoki
# Paul Oakenfold  vs. Daft Punk
# Benny Benassi vs. Daft Punk
# Steve Aoki vs. Daft Punk
# Ron Hardy vs. Paul Oakenfold
#
# Group 14:
# DJ Funk
# Dajae
# Laidback Luke
# Bomb The Bass
#
# DJ Funk vs. Bomb The Bass
# Dajae vs. Laidback Luke
# Dajae vs. Bomb The Bass
# Laidback Luke vs. Bomb The Bass
# Dajae vs. DJ Funk
# Laidback Luke vs. DJ Funk
#
# Group 15:
# Derrick May
# Farley "Jackmaster" Funk
# Hardwell
# Aphex Twin
# Dada Nada
#
# Aphex Twin vs. Derrick May
# Aphex Twin vs. Hardwell
# Aphex Twin vs. Farley "Jackmaster" Funk
# Dada Nada vs. Farley "Jackmaster" Funk
# Dada Nada vs. Hardwell
# Farley "Jackmaster" Funk vs. Hardwell
# Dada Nada vs. Aphex Twin
# Derrick May vs. Dada Nada
# Hardwell vs. Derrick May
# Farley "Jackmaster" Funk vs. Derrick May
#
# Group 16:
# Pet Shop Boys
# Paul Johnson
# DJ Falcon
# Alvaro
# Vince Lawrence
#
# Alvaro vs. Vince Lawrence
# Paul Johnson vs. Pet Shop Boys
# DJ Falcon vs. Paul Johnson
# DJ Falcon vs. Pet Shop Boys
# Paul Johnson vs. Vince Lawrence
# Alvaro vs. Paul Johnson
# Alvaro vs. DJ Falcon
# Alvaro vs. Pet Shop Boys
# DJ Falcon vs. Vince Lawrence
# Vince Lawrence vs. Pet Shop Boys
#
# Group 17:
# Steve "Silk" Hurley
# R3hab
# Cerrone
# Robin S
# Krush
#
# Robin S vs. Cerrone
# Robin S vs. Steve "Silk" Hurley
# Krush vs. Cerrone
# Steve "Silk" Hurley vs. Cerrone
# Cerrone vs. R3hab
# Steve "Silk" Hurley vs. R3hab
# R3hab vs. Robin S
# Steve "Silk" Hurley vs. Krush
# Krush vs. Robin S
# R3hab vs. Krush
#
# Group 18:
# Mr. Fingers
# Juan Atkins
# Fingers, Inc.
# Stardust
# Chuckie
#
# Fingers, Inc. vs. Juan Atkins
# Mr. Fingers vs. Chuckie
# Chuckie vs. Fingers, Inc.
# Mr. Fingers vs. Fingers, Inc.
# Stardust vs. Chuckie
# Juan Atkins vs. Stardust
# Juan Atkins vs. Chuckie
# Mr. Fingers vs. Juan Atkins
# Fingers, Inc. vs. Stardust
# Stardust vs. Mr. Fingers
#
# Group 19:
# Mickey Oliver
# Darryl Pandy
# DJ Irene
# Swedish House Mafia
#
# DJ Irene vs. Darryl Pandy
# Swedish House Mafia vs. Darryl Pandy
# Darryl Pandy vs. Mickey Oliver
# DJ Irene vs. Swedish House Mafia
# DJ Irene vs. Mickey Oliver
# Swedish House Mafia vs. Mickey Oliver
#
# Group 20:
# The Style Council
# Mirage
# Kylie Minogue
# James Brown
# Lime
#
# James Brown vs. Lime
# Kylie Minogue vs. Lime
# Mirage vs. James Brown
# Mirage vs. Lime
# Mirage vs. Kylie Minogue
# The Style Council vs. Kylie Minogue
# The Style Council vs. Lime
# Kylie Minogue vs. James Brown
# Mirage vs. The Style Council
# James Brown vs. The Style Council
#
# Group 21:
# Dennis Ferrer
# Sebastian Ingrosso
# Fast Eddie
# Timmy Regisford
# Kevin Saunderson
#
# Timmy Regisford vs. Dennis Ferrer
# Kevin Saunderson vs. Sebastian Ingrosso
# Dennis Ferrer vs. Kevin Saunderson
# Sebastian Ingrosso vs. Timmy Regisford
# Kevin Saunderson vs. Timmy Regisford
# Kevin Saunderson vs. Fast Eddie
# Fast Eddie vs. Dennis Ferrer
# Dennis Ferrer vs. Sebastian Ingrosso
# Fast Eddie vs. Sebastian Ingrosso
# Fast Eddie vs. Timmy Regisford
#
# Group 22:
# Masters at Work
# Trans-X
# Avicii
# Phuture
# Todd Terry
#
# Phuture vs. Avicii
# Phuture vs. Trans-X
# Todd Terry vs. Phuture
# Todd Terry vs. Masters at Work
# Masters at Work vs. Trans-X
# Masters at Work vs. Phuture
# Avicii vs. Todd Terry
# Avicii vs. Masters at Work
# Todd Terry vs. Trans-X
# Avicii vs. Trans-X
#
# Group 23:
# Deee-Lite
# Blackbox
# Quintino
# Arthur Baker
# Walter Gibbons
#
# Arthur Baker vs. Quintino
# Blackbox vs. Walter Gibbons
# Walter Gibbons vs. Arthur Baker
# Quintino vs. Walter Gibbons
# Blackbox vs. Quintino
# Deee-Lite vs. Walter Gibbons
# Deee-Lite vs. Blackbox
# Arthur Baker vs. Blackbox
# Arthur Baker vs. Deee-Lite
# Deee-Lite vs. Quintino
#
# Group 24:
# Whitney Houston
# Diplo
# Calvin Harris
# Mel and Kim
# Kygo
#
# Whitney Houston vs. Calvin Harris
# Whitney Houston vs. Diplo
# Mel and Kim  vs. Calvin Harris
# Calvin Harris vs. Diplo
# Calvin Harris vs. Kygo
# Kygo vs. Whitney Houston
# Mel and Kim  vs. Whitney Houston
# Diplo vs. Kygo
# Kygo vs. Mel and Kim
# Mel and Kim  vs. Diplo
#
# Group 25:
# Above & Beyond
# Frankie Knuckles
# Nightcrawlers
# S-Express
#
# S-Express vs. Nightcrawlers
# Frankie Knuckles vs. S-Express
# S-Express vs. Above & Beyond
# Frankie Knuckles vs. Above & Beyond
# Nightcrawlers vs. Above & Beyond
# Frankie Knuckles vs. Nightcrawlers
#
# Group 26:
# Fonzerelli
# Steve "Silk" Hurley
# SHINee
# Mr. C
# Jeff Mills
#
# Mr. C vs. SHINee
# Mr. C vs. Jeff Mills
# Steve "Silk" Hurley vs. SHINee
# Jeff Mills vs. Steve "Silk" Hurley
# Mr. C vs. Fonzerelli
# Jeff Mills vs. SHINee
# SHINee vs. Fonzerelli
# Steve "Silk" Hurley vs. Mr. C
# Fonzerelli vs. Steve "Silk" Hurley
# Fonzerelli vs. Jeff Mills
#
# Group 27:
# DJ Lynnwood
# Cybotron
# Steve Angello
# Larry Levan
# Bad Boy Bill
#
# DJ Lynnwood vs. Cybotron
# Cybotron vs. Larry Levan
# Bad Boy Bill vs. Larry Levan
# Larry Levan vs. DJ Lynnwood
# Steve Angello vs. Larry Levan
# DJ Lynnwood vs. Bad Boy Bill
# DJ Lynnwood vs. Steve Angello
# Bad Boy Bill vs. Cybotron
# Bad Boy Bill vs. Steve Angello
# Cybotron vs. Steve Angello
#
# Group 28:
# Kraftwerk
# Armando Gallop
# Inner City
# EBN-OZN
# Rheji Burrell
#
# Rheji Burrell vs. Armando Gallop
# EBN-OZN vs. Armando Gallop
# Rheji Burrell vs. Inner City
# Rheji Burrell vs. Kraftwerk
# Kraftwerk vs. Inner City
# Kraftwerk vs. EBN-OZN
# Armando Gallop vs. Kraftwerk
# Inner City vs. EBN-OZN
# Inner City vs. Armando Gallop
# Rheji Burrell vs. EBN-OZN
#
# Group 29:
# Yellow Magic Orchestra
# David Guetta
# Beatmasters
# Lil Louis
# Eric Prydz
#
# Yellow Magic Orchestra vs. Eric Prydz
# Lil Louis vs. David Guetta
# Lil Louis vs. Eric Prydz
# Beatmasters vs. Eric Prydz
# Lil Louis vs. Beatmasters
# Beatmasters vs. Yellow Magic Orchestra
# Eric Prydz vs. David Guetta
# David Guetta vs. Beatmasters
# Yellow Magic Orchestra vs. David Guetta
# Lil Louis vs. Yellow Magic Orchestra
#
# Group 30:
# Joe Smooth
# M & M
# Phuture
# Madonna
#
# Madonna vs. Phuture
# Madonna vs. M & M
# Madonna vs. Joe Smooth
# Phuture vs. M & M
# M & M vs. Joe Smooth
# Joe Smooth vs. Phuture
#
# Group 31:
# Richard "Humpty" Vission
# Jesse Saunders
# Bobby O
# Leftfield
# DJ Sneak
#
# Richard "Humpty" Vission vs. Leftfield
# Jesse Saunders vs. Bobby O
# Richard "Humpty" Vission vs. DJ Sneak
# Bobby O vs. DJ Sneak
# DJ Sneak vs. Leftfield
# Bobby O vs. Leftfield
# Bobby O vs. Richard "Humpty" Vission
# Leftfield vs. Jesse Saunders
# Jesse Saunders vs. Richard "Humpty" Vission
# Jesse Saunders vs. DJ Sneak
#
# Group 32:
# Kaskade
# Colonel Abrams
# Axwell
# Cassius
# Frankie Knuckles
#
# Frankie Knuckles vs. Cassius
# Colonel Abrams vs. Kaskade
# Frankie Knuckles vs. Colonel Abrams
# Frankie Knuckles vs. Kaskade
# Axwell vs. Kaskade
# Axwell vs. Colonel Abrams
# Kaskade vs. Cassius
# Frankie Knuckles vs. Axwell
# Colonel Abrams vs. Cassius
# Cassius  vs. Axwell

# %% [markdown]
# What would be even cooler, but seems much more difficult:
#     Figure out how to automatically extract the data from a webpage - make a program that will create my list for me in the first place by taking that data.
#     Have it pull up Spotify, search for the artist, and play a song by that artist by going to their spotify artist page and randomly shuffling - so it would be automatic. I would just run my program, and it would go through the tournament on its own and then ask me to pick a winner, then store that value.

# %%
def shuffled_list(filename):
    unshuffled_list = read_list(filename)
    shuffled = random.shuffle(unshuffled_list)
    return shuffled

# %%
pair_artists("tappatourney.txt")
# Out:
# Group 1:
# Free Will
# Moving Target
# Pieces of a Man
# Save the Children
# Nothing New
# Small Talk at 125th and Lenox
#
# Free Will vs. Moving Target
# Pieces of a Man vs. Free Will
# Pieces of a Man vs. Nothing New
# Pieces of a Man vs. Moving Target
# Small Talk at 125th and Lenox vs. Free Will
# Save the Children vs. Nothing New
# Save the Children vs. Small Talk at 125th and Lenox
# Free Will vs. Save the Children
# Free Will vs. Nothing New
# Small Talk at 125th and Lenox vs. Nothing New
# Nothing New vs. Moving Target
# Small Talk at 125th and Lenox vs. Moving Target
# Pieces of a Man vs. Save the Children
# Moving Target vs. Save the Children
# Small Talk at 125th and Lenox vs. Pieces of a Man
#
# Group 2:
# Spirits
# I'm New Here
# We're New Again
# The First Minute of a New Day
# 1980
# Reflections
#
# 1980 vs. Spirits
# 1980 vs. I'm New Here
# We're New Again vs. I'm New Here
# The First Minute of a New Day vs. Reflections
# We're New Again vs. The First Minute of a New Day
# I'm New Here vs. Spirits
# The First Minute of a New Day vs. 1980
# Reflections vs. We're New Again
# Spirits vs. Reflections
# I'm New Here vs. Reflections
# 1980 vs. Reflections
# The First Minute of a New Day vs. I'm New Here
# Spirits vs. The First Minute of a New Day
# Spirits vs. We're New Again
# 1980 vs. We're New Again
#
# Group 3:
# Live at the Town and Country 1988
# The Mind of Gil Scott-Heron
# Secrets
# Greatest Hits Live: Collector Series
# Minister of Information: Live
# Winter in America
# It's Your World
#
# Winter in America vs. Greatest Hits Live: Collector Series
# Winter in America vs. The Mind of Gil Scott-Heron
# Greatest Hits Live: Collector Series vs. The Mind of Gil Scott-Heron
# It's Your World vs. The Mind of Gil Scott-Heron
# The Mind of Gil Scott-Heron vs. Secrets
# Minister of Information: Live vs. Greatest Hits Live: Collector Series
# It's Your World vs. Minister of Information: Live
# Winter in America vs. Live at the Town and Country 1988
# Winter in America vs. Secrets
# Winter in America vs. Minister of Information: Live
# Winter in America vs. It's Your World
# Live at the Town and Country 1988 vs. The Mind of Gil Scott-Heron
# Live at the Town and Country 1988 vs. It's Your World
# Secrets vs. Live at the Town and Country 1988
# Minister of Information: Live vs. Secrets
# Live at the Town and Country 1988 vs. Minister of Information: Live
# Secrets vs. It's Your World
# Minister of Information: Live vs. The Mind of Gil Scott-Heron
# Greatest Hits Live: Collector Series vs. Secrets
# Greatest Hits Live: Collector Series vs. It's Your World
# Live at the Town and Country 1988 vs. Greatest Hits Live: Collector Series
#
# Group 4:
# Real Eyes
# Bridges
# Tales of Gil Scott-Heron and His Amnesia Express
# It's Your World
# From South Africa to South Carolina
# The Best of Gil Scott-Heron Live
#
# The Best of Gil Scott-Heron Live vs. It's Your World
# The Best of Gil Scott-Heron Live vs. Real Eyes
# Bridges vs. Real Eyes
# Bridges vs. Tales of Gil Scott-Heron and His Amnesia Express
# Bridges vs. The Best of Gil Scott-Heron Live
# Real Eyes vs. From South Africa to South Carolina
# It's Your World vs. From South Africa to South Carolina
# From South Africa to South Carolina vs. The Best of Gil Scott-Heron Live
# Tales of Gil Scott-Heron and His Amnesia Express vs. From South Africa to South Carolina
# It's Your World vs. Real Eyes
# From South Africa to South Carolina vs. Bridges
# It's Your World vs. Tales of Gil Scott-Heron and His Amnesia Express
# It's Your World vs. Bridges
# The Best of Gil Scott-Heron Live vs. Tales of Gil Scott-Heron and His Amnesia Express
# Real Eyes vs. Tales of Gil Scott-Heron and His Amnesia Express
